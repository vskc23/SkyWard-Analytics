# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Birdstrike
# Out:
# /content/drive/MyDrive/Birdstrike

# %%
import pandas as pd
transport_df = pd.read_csv('/content/drive/MyDrive/Transport/combined_transport_data.csv')

# %%
transport_df.head()
# Out:
#    YEAR  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK               FL_DATE  \
# 0  2022        3      9             1            4  9/1/2022 12:00:00 AM
# 1  2022        3      9             1            4  9/1/2022 12:00:00 AM
# 2  2022        3      9             1            4  9/1/2022 12:00:00 AM
# 3  2022        3      9             1            4  9/1/2022 12:00:00 AM
# 4  2022        3      9             1            4  9/1/2022 12:00:00 AM
#
#   OP_UNIQUE_CARRIER  OP_CARRIER_AIRLINE_ID OP_CARRIER TAIL_NUM  ...  TAXI_OUT  \
# 0                9E                  20363         9E   N131EV  ...      19.0
# 1                9E                  20363         9E   N131EV  ...      25.0
# 2                9E                  20363         9E   N131EV  ...      13.0
# 3                9E                  20363         9E   N131EV  ...      18.0
# 4                9E                  20363         9E   N131EV  ...      21.0
#
# ...

# %%
transport_df.columns
# Out:
# Index(['YEAR', 'QUARTER', 'MONTH', 'DAY_OF_MONTH', 'DAY_OF_WEEK', 'FL_DATE',
#        'OP_UNIQUE_CARRIER', 'OP_CARRIER_AIRLINE_ID', 'OP_CARRIER', 'TAIL_NUM',
#        'OP_CARRIER_FL_NUM', 'ORIGIN_AIRPORT_ID', 'ORIGIN_AIRPORT_SEQ_ID',
#        'ORIGIN_CITY_MARKET_ID', 'ORIGIN', 'ORIGIN_CITY_NAME',
#        'ORIGIN_STATE_ABR', 'ORIGIN_STATE_FIPS', 'ORIGIN_STATE_NM',
#        'ORIGIN_WAC', 'DEST_AIRPORT_ID', 'DEST_AIRPORT_SEQ_ID',
#        'DEST_CITY_MARKET_ID', 'DEST', 'DEST_CITY_NAME', 'DEST_STATE_ABR',
#        'DEST_STATE_NM', 'DEP_TIME', 'DEP_DELAY', 'DEP_DELAY_NEW', 'DEP_DEL15',
#        'TAXI_OUT', 'WHEELS_OFF', 'CANCELLED', 'CANCELLATION_CODE', 'DIVERTED',
#        'AIR_TIME', 'FLIGHTS', 'CARRIER_DELAY', 'WEATHER_DELAY', 'NAS_DELAY'],
#       dtype='object')

# %%
transport_df.drop(columns=['YEAR', 'QUARTER', 'MONTH', 'DAY_OF_MONTH', 'DAY_OF_WEEK', 'OP_UNIQUE_CARRIER', 'OP_CARRIER_AIRLINE_ID', 'OP_CARRIER', 'TAIL_NUM', 'OP_CARRIER_FL_NUM', 'ORIGIN_AIRPORT_ID', 'ORIGIN_AIRPORT_SEQ_ID', 'ORIGIN_CITY_MARKET_ID', 'ORIGIN_CITY_NAME','ORIGIN_STATE_ABR', 'ORIGIN_STATE_FIPS', 'ORIGIN_STATE_NM','ORIGIN_WAC', 'DEST_AIRPORT_ID', 'DEST_AIRPORT_SEQ_ID','DEST_CITY_MARKET_ID', 'DEST_CITY_NAME', 'DEST_STATE_ABR','DEST_STATE_NM', 'DEP_TIME', 'DEP_DELAY', 'DEP_DELAY_NEW','TAXI_OUT', 'WHEELS_OFF', 'CANCELLED', 'CANCELLATION_CODE', 'DIVERTED','AIR_TIME', 'FLIGHTS', 'CARRIER_DELAY', 'NAS_DELAY'], inplace=True)

# %%
transport_df.head()
# Out:
#                 FL_DATE ORIGIN DEST  DEP_DEL15  WEATHER_DELAY
# 0  9/1/2022 12:00:00 AM    LGA  RDU        0.0            NaN
# 1  9/1/2022 12:00:00 AM    LGA  RIC        0.0            NaN
# 2  9/1/2022 12:00:00 AM    RIC  LGA        0.0            NaN
# 3  9/1/2022 12:00:00 AM    BDL  LGA        0.0            NaN
# 4  9/1/2022 12:00:00 AM    CHO  LGA        0.0            NaN

# %%
transport_df = pd.read_csv("/content/drive/MyDrive/weather dataset/transport.csv")
transport_df.head()
# Out:
#                 FL_DATE  ORIGIN_AIRPORT_ID  DEST_AIRPORT_ID  ARR_DEL15
# 0  9/1/2019 12:00:00 AM              10135            10397        0.0
# 1  9/1/2019 12:00:00 AM              10135            10397        0.0
# 2  9/1/2019 12:00:00 AM              10135            11057        0.0
# 3  9/1/2019 12:00:00 AM              10135            11433        0.0
# 4  9/1/2019 12:00:00 AM              10135            11433        0.0

# %%
transport_df['FL_DATE'] = pd.to_datetime(transport_df['FL_DATE'])

# Format 'Date' column to display only date part
transport_df['FL_DATE'] = transport_df['FL_DATE'].dt.date
# Out:
# <ipython-input-32-23611c5e1f25>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   transport_df['FL_DATE'] = pd.to_datetime(transport_df['FL_DATE'])

# %%
transport_df.head()
# Out:
#       FL_DATE ORIGIN DEST  DEP_DEL15  WEATHER_DELAY
# 0  2022-09-01    LGA  RDU        0.0            NaN
# 1  2022-09-01    LGA  RIC        0.0            NaN
# 2  2022-09-01    RIC  LGA        0.0            NaN
# 3  2022-09-01    BDL  LGA        0.0            NaN
# 4  2022-09-01    CHO  LGA        0.0            NaN

# %%
transport_df["ORIGIN"].sort_values().unique()
# Out:
# array(['ABE', 'ABI', 'ABQ', 'ABR', 'ABY', 'ACK', 'ACT', 'ACV', 'ACY',
#        'ADK', 'ADQ', 'AEX', 'AGS', 'AKN', 'ALB', 'ALO', 'ALS', 'ALW',
#        'AMA', 'ANC', 'APN', 'ASE', 'ATL', 'ATW', 'ATY', 'AUS', 'AVL',
#        'AVP', 'AZA', 'AZO', 'BDL', 'BET', 'BFF', 'BFL', 'BFM', 'BGM',
#        'BGR', 'BHM', 'BIH', 'BIL', 'BIS', 'BJI', 'BKG', 'BLI', 'BLV',
#        'BMI', 'BNA', 'BOI', 'BOS', 'BPT', 'BQK', 'BQN', 'BRD', 'BRO',
#        'BRW', 'BTM', 'BTR', 'BTV', 'BUF', 'BUR', 'BWI', 'BZN', 'CAE',
#        'CAK', 'CDB', 'CDC', 'CDV', 'CGI', 'CHA', 'CHO', 'CHS', 'CID',
#        'CIU', 'CKB', 'CLE', 'CLL', 'CLT', 'CMH', 'CMI', 'CMX', 'CNY',
#        'COD', 'COS', 'COU', 'CPR', 'CRP', 'CRW', 'CSG', 'CVG', 'CWA',
#        'CYS', 'DAB', 'DAL', 'DAY', 'DBQ', 'DCA', 'DDC', 'DEC', 'DEN',
#        'DFW', 'DHN', 'DIK', 'DLG', 'DLH', 'DRO', 'DRT', 'DSM', 'DTW',
#        'DVL', 'EAR', 'EAT', 'EAU', 'ECP', 'EGE', 'EKO', 'ELM', 'ELP',
# ...

# %%
transport_df["DEST"].sort_values().unique()
# Out:
# array(['ABE', 'ABI', 'ABQ', 'ABR', 'ABY', 'ACK', 'ACT', 'ACV', 'ACY',
#        'ADK', 'ADQ', 'AEX', 'AGS', 'AKN', 'ALB', 'ALO', 'ALS', 'ALW',
#        'AMA', 'ANC', 'APN', 'ASE', 'ATL', 'ATW', 'ATY', 'AUS', 'AVL',
#        'AVP', 'AZA', 'AZO', 'BDL', 'BET', 'BFF', 'BFL', 'BFM', 'BGM',
#        'BGR', 'BHM', 'BIH', 'BIL', 'BIS', 'BJI', 'BKG', 'BLI', 'BLV',
#        'BMI', 'BNA', 'BOI', 'BOS', 'BPT', 'BQK', 'BQN', 'BRD', 'BRO',
#        'BRW', 'BTM', 'BTR', 'BTV', 'BUF', 'BUR', 'BWI', 'BZN', 'CAE',
#        'CAK', 'CDB', 'CDC', 'CDV', 'CGI', 'CHA', 'CHO', 'CHS', 'CID',
#        'CIU', 'CKB', 'CLE', 'CLL', 'CLT', 'CMH', 'CMI', 'CMX', 'CNY',
#        'COD', 'COS', 'COU', 'CPR', 'CRP', 'CRW', 'CSG', 'CVG', 'CWA',
#        'CYS', 'DAB', 'DAL', 'DAY', 'DBQ', 'DCA', 'DDC', 'DEC', 'DEN',
#        'DFW', 'DHN', 'DIK', 'DLG', 'DLH', 'DRO', 'DRT', 'DSM', 'DTW',
#        'DVL', 'EAR', 'EAT', 'EAU', 'ECP', 'EGE', 'EKO', 'ELM', 'ELP',
# ...

# %%
weather_df.head()
# Out:
#        STATION  DEST_AIRPORT_ID  LATITUDE  LONGITUDE  ELEVATION   FL_DATE  \
# 0  USW00094846            13930  41.96017  -87.93164      204.8  9/1/2019
# 1  USW00094846            13930  41.96017  -87.93164      204.8  9/2/2019
# 2  USW00094846            13930  41.96017  -87.93164      204.8  9/3/2019
# 3  USW00094846            13930  41.96017  -87.93164      204.8  9/4/2019
# 4  USW00094846            13930  41.96017  -87.93164      204.8  9/5/2019
#
#     AWND  PRCP  SNOW  SNWD  TAVG  TMAX  TMIN
# 0   4.47  0.34   0.0   0.0    67    73    62
# 1   6.49  0.00   0.0   0.0    70    82    61
# 2  12.30  0.22   0.0   0.0    72    80    67
# 3   8.95  0.00   0.0   0.0    68    69    59
# 4   4.92  0.00   0.0   0.0    64    74    56

# %%
result = pd.merge(weather_df, transport_df, on=['DEST_AIRPORT_ID', 'FL_DATE'], how='inner')

# %%
result.shape
# Out:
# (0, 15)
